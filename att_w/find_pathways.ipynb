# %%
f = open('../data/html/CD2.txt', 'r')
lines = f.readlines()

# %%
pathways = []
for idx, line in enumerate(lines):
    if len(line.split(' ')) == 1:
        pathways.append(line)
# Out:
# CD2AP
#
# CD2BP2
#
# SH3KBP1
#
# FYN
#
# LCK
#
# PSTPIP1
#
# CD247
#
# CD28
#
# CD4
#
# CD48
#
# CD5
#
# CD53
#
# CD58
#
# CD59
#
# EP300
#
# ITK
#
# LGALS1
#
# PAG1
#
# PIK3R1
#
# PTPRC
#
# SP1
#
# SYK
#
# ADAM15
#
# ADAMDEC1
#
# AIF1
#
# ARHGAP15
#
# ARHGAP25
#
# ASAP1
#
# B2M
#
# BCAM
#
# BCAR1
#
# BIN2
#
# BLNK
#
# BTLA
#
# BTN2A2
#
# BTN3A1
#
# BTN3A3
#
# BTNL2
#
# BTNL8
#
# BTNL9
#
# BZW1
#
# C1QA
#
# C1QB
#
# C1QC
#
# C2
#
# C3
#
# CADM1
#
# CADM3
#
# CASP8
#
# CAV1
#
# CBL
#
# CCL19
#
# CCL5
#
# CCN2
#
# CCR5
#
# CCR7
#
# CCRL2
#
# CD101
#
# CD1D
#
# CD200R1
#
# CD22
#
# CD27
#
# CD274
#
# CD276
#
# CD300A
#
# CD300LF
#
# CD33
#
# CD36
#
# CD37
#
# CD38
#
# CD3D
#
# CD3E
#
# CD3G
#
# CD40
#
# CD40LG
#
# CD47
#
# CD52
#
# CD6
#
# CD69
#
# CD7
#
# CD72
#
# CD74
#
# CD79A
#
# CD80
#
# CD83
#
# CD84
#
# CD86
#
# CD8A
#
# CD8B
#
# CD93
#
# CD96
#
# CDH13
#
# CEACAM1
#
# CEACAM16
#
# CEACAM21
#
# CEACAM3
#
# CEACAM4
#
# CEACAM5
#
# CEACAM7
#
# CFLAR
#
# CILP2
#
# CKS1B
#
# COL14A1
# ...
